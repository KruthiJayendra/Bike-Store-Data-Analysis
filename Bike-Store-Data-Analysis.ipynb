# %% [markdown]
# # DATA ANALYSIS OF BIKESTORE DB USING SQL QUERIES

# %% [markdown]
# ### Importing the Libraries

# %%
import pandas as pd
import numpy as np
import sqlite3 as sql
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# ### Reading the CSV files

# %%
brands = pd.read_csv('brands.csv')
categories = pd.read_csv('categories.csv')
customers = pd.read_csv('customers.csv')
order_items = pd.read_csv('order_items.csv')
orders = pd.read_csv('orders.csv')
products = pd.read_csv('products.csv')
staffs = pd.read_csv('staffs.csv')
stocks = pd.read_csv('stocks.csv')
stores = pd.read_csv('stores.csv')

# %% [markdown]
# ### Create a Database Connection

# %%
db=sql.connect('bike_store_db')

# %% [markdown]
# ### Inserting data into Database

# %%
print("Number rows in brands:" + str(brands.to_sql('brands', db , if_exists='replace', index=False)))
print("Number rows in categories:" + str(categories.to_sql('categories', db , if_exists='replace', index=False)))
print("Number rows in customers:" + str(customers.to_sql('customers', db , if_exists='replace', index=False)))
print("Number rows in order_items:" + str(order_items.to_sql('order_items', db , if_exists='replace', index=False)))
print("Number rows in orders:" + str(orders.to_sql('orders', db , if_exists='replace', index=False)))
print("Number rows in products:" + str(products.to_sql('products', db , if_exists='replace', index=False)))
print("Number rows in staffs:" + str(staffs.to_sql('staffs', db , if_exists='replace', index=False)))
print("Number rows in stocks:" + str(stocks.to_sql('stocks', db , if_exists='replace', index=False)))
print("Number rows in stores:" + str(stores.to_sql('stores', db , if_exists='replace', index=False)))
# Out:
# Number rows in brands:9
# Number rows in categories:7
# Number rows in customers:1445
# Number rows in order_items:4722
# Number rows in orders:1615
# Number rows in products:321
# Number rows in staffs:10
# Number rows in stocks:939
# Number rows in stores:3

# %% [markdown]
# ### Show tables using SQL queries

# %%
q1='''
SELECT * FROM brands;
'''

df1= pd.read_sql_query(q1,db)
df1
# Out:
#    brand_id    brand_name
# 0         1       Electra
# 1         2          Haro
# 2         3        Heller
# 3         4   Pure Cycles
# 4         5       Ritchey
# 5         6       Strider
# 6         7  Sun Bicycles
# 7         8         Surly
# 8         9          Trek

# %%
q2= '''
SELECT * FROM categories
'''

df2=pd.read_sql_query(q2,db)
df2
# Out:
#    category_id        category_name
# 0            1    Children Bicycles
# 1            2     Comfort Bicycles
# 2            3    Cruisers Bicycles
# 3            4  Cyclocross Bicycles
# 4            5       Electric Bikes
# 5            6       Mountain Bikes
# 6            7           Road Bikes

# %%
q3='''
SELECT * FROM customers
'''

df3=pd.read_sql_query(q3,db)
df3
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks            None
# 1               2       Kasha      Todd            None
# 2               3      Tameka    Fisher            None
# 3               4       Daryl    Spence            None
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 1440         1441      Jamaal  Morrison            None
# 1441         1442      Cassie     Cline            None
# 1442         1443      Lezlie      Lamb            None
# 1443         1444      Ivette     Estes            None
# 1444         1445       Ester   Acevedo            None
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# 2       tameka.fisher@aol.com   769C Honey Creek St.   Redondo Beach    CA
# 3        daryl.spence@aol.com         988 Pearl Lane       Uniondale    NY
# 4     charolette.rice@msn.com          107 River Dr.      Sacramento    CA
# ...                       ...                     ...            ...   ...
# 1440  jamaal.morrison@msn.com  796 SE. Nut Swamp St.   Staten Island    NY
# 1441   cassie.cline@gmail.com    947 Lafayette Drive        Brooklyn    NY
# 1442    lezlie.lamb@gmail.com  401 Brandywine Street   Central Islip    NY
# 1443   ivette.estes@gmail.com  88 N. Canterbury Ave.     Canandaigua    NY
# 1444  ester.acevedo@gmail.com        671 Miles Court     San Lorenzo    CA
#
#       zip_code
# 0        14127
# 1        95008
# 2        90278
# 3        11553
# 4        95820
# ...        ...
# 1440     10301
# 1441     11201
# 1442     11722
# 1443     14424
# 1444     94580
#
# [1445 rows x 9 columns]

# %%
q4='''
SELECT * FROM order_items
'''
df4= pd.read_sql_query(q4,db)
df4
# Out:
#       order_id  item_id  product_id  quantity  list_price  discount
# 0            1        1          20         1      599.99      0.20
# 1            1        2           8         2     1799.99      0.07
# 2            1        3          10         2     1549.00      0.05
# 3            1        4          16         2      599.99      0.05
# 4            1        5           4         1     2899.99      0.20
# ...        ...      ...         ...       ...         ...       ...
# 4717      1614        2         159         2     2299.99      0.07
# 4718      1614        3         213         2      269.99      0.20
# 4719      1615        1         197         2     2299.99      0.20
# 4720      1615        2         214         1      899.99      0.07
# 4721      1615        3         182         1     2499.99      0.20
#
# [4722 rows x 6 columns]

# %%
q5='''
SELECT * FROM orders
'''
df5= pd.read_sql_query(q5,db)
df5
# Out:
#       order_id  customer_id  order_status  order_date required_date  \
# 0            1          259             4  2016-01-01    2016-01-03
# 1            2         1212             4  2016-01-01    2016-01-04
# 2            3          523             4  2016-01-02    2016-01-05
# 3            4          175             4  2016-01-03    2016-01-04
# 4            5         1324             4  2016-01-03    2016-01-06
# ...        ...          ...           ...         ...           ...
# 1610      1611            6             3  2018-09-06    2018-09-06
# 1611      1612            3             3  2018-10-21    2018-10-21
# 1612      1613            1             3  2018-11-18    2018-11-18
# 1613      1614          135             3  2018-11-28    2018-11-28
# 1614      1615          136             3  2018-12-28    2018-12-28
#
#      shipped_date  store_id  staff_id
# 0      2016-01-03         1         2
# 1      2016-01-03         2         6
# 2      2016-01-03         2         7
# 3      2016-01-05         1         3
# 4      2016-01-06         2         6
# ...           ...       ...       ...
# 1610         None         2         7
# 1611         None         1         3
# 1612         None         2         6
# 1613         None         3         8
# 1614         None         3         8
#
# [1615 rows x 8 columns]

# %%
q6='''
SELECT * FROM products
'''

df6= pd.read_sql_query(q6,db)
df6
# Out:
#      product_id                          product_name  brand_id  category_id  \
# 0             1                       Trek 820 - 2016         9            6
# 1             2    Ritchey Timberwolf Frameset - 2016         5            6
# 2             3       Surly Wednesday Frameset - 2016         8            6
# 3             4              Trek Fuel EX 8 29 - 2016         9            6
# 4             5          Heller Shagamaw Frame - 2016         3            6
# ..          ...                                   ...       ...          ...
# 316         317          Trek Checkpoint ALR 5 - 2019         9            7
# 317         318  Trek Checkpoint ALR 5 Women's - 2019         9            7
# 318         319   Trek Checkpoint SL 5 Women's - 2019         9            7
# 319         320           Trek Checkpoint SL 6 - 2019         9            7
# 320         321   Trek Checkpoint ALR Frameset - 2019         9            7
#
#      model_year  list_price
# 0          2016      379.99
# 1          2016      749.99
# 2          2016      999.99
# 3          2016     2899.99
# 4          2016     1320.99
# ..          ...         ...
# 316        2019     1999.99
# 317        2019     1999.99
# 318        2019     2799.99
# 319        2019     3799.99
# 320        2019     3199.99
#
# [321 rows x 6 columns]

# %%
q7='''
SELECT * FROM staffs
'''

df7= pd.read_sql_query(q7,db)
df7
# Out:
#    staff_id  first_name last_name                          email  \
# 0         1     Fabiola   Jackson     fabiola.jackson@bikes.shop
# 1         2      Mireya  Copeland     mireya.copeland@bikes.shop
# 2         3       Genna   Serrano       genna.serrano@bikes.shop
# 3         4      Virgie   Wiggins      virgie.wiggins@bikes.shop
# 4         5    Jannette     David      jannette.david@bikes.shop
# 5         6   Marcelene     Boyer     marcelene.boyer@bikes.shop
# 6         7      Venita    Daniel       venita.daniel@bikes.shop
# 7         8        Kali    Vargas         kali.vargas@bikes.shop
# 8         9       Layla   Terrell       layla.terrell@bikes.shop
# 9        10  Bernardine   Houston  bernardine.houston@bikes.shop
#
#             phone  active  store_id  manager_id
# 0  (831) 555-5554       1         1         NaN
# 1  (831) 555-5555       1         1         1.0
# 2  (831) 555-5556       1         1         2.0
# 3  (831) 555-5557       1         1         2.0
# 4  (516) 379-4444       1         2         1.0
# 5  (516) 379-4445       1         2         5.0
# 6  (516) 379-4446       1         2         5.0
# 7  (972) 530-5555       1         3         1.0
# 8  (972) 530-5556       1         3         7.0
# 9  (972) 530-5557       1         3         7.0

# %%
q8='''
SELECT * FROM stocks
'''
df8= pd.read_sql_query(q8,db)
df8
# Out:
#      store_id  product_id  quantity
# 0           1           1        27
# 1           1           2         5
# 2           1           3         6
# 3           1           4        23
# 4           1           5        22
# ..        ...         ...       ...
# 934         3         309        30
# 935         3         310         8
# 936         3         311        23
# 937         3         312        18
# 938         3         313         0
#
# [939 rows x 3 columns]

# %%
q9='''
SELECT * FROM stores
'''
df9= pd.read_sql_query(q9,db)
df9
# Out:
#    store_id        store_name           phone                 email  \
# 0         1  Santa Cruz Bikes  (831) 476-4321  santacruz@bikes.shop
# 1         2     Baldwin Bikes  (516) 379-8888    baldwin@bikes.shop
# 2         3     Rowlett Bikes  (972) 530-5555    rowlett@bikes.shop
#
#                 street        city state  zip_code
# 0   3700 Portola Drive  Santa Cruz    CA     95060
# 1   4200 Chestnut Lane     Baldwin    NY     11432
# 2  8000 Fairway Avenue     Rowlett    TX     75088

# %% [markdown]
# # Analysis

# %% [markdown]
# ### Number of stocks based on category name and store name

# %%
query1 ='''
SELECT store_name , category_name, SUM(quantity) as sum_qty
FROM categories
JOIN products ON categories.category_id = products.category_id
JOIN stocks ON products.product_id = stocks.product_id
JOIN stores ON stocks.store_id = stores.store_id
GROUP BY store_name, category_name
ORDER BY store_name, category_name;'''

result1= pd.read_sql_query(query1,db)
result1
# Out:
#           store_name        category_name  sum_qty
# 0      Baldwin Bikes    Children Bicycles      769
# 1      Baldwin Bikes     Comfort Bicycles      393
# 2      Baldwin Bikes    Cruisers Bicycles     1137
# 3      Baldwin Bikes  Cyclocross Bicycles       97
# 4      Baldwin Bikes       Electric Bikes      328
# 5      Baldwin Bikes       Mountain Bikes      877
# 6      Baldwin Bikes           Road Bikes      758
# 7      Rowlett Bikes    Children Bicycles      887
# 8      Rowlett Bikes     Comfort Bicycles      440
# 9      Rowlett Bikes    Cruisers Bicycles     1148
# 10     Rowlett Bikes  Cyclocross Bicycles      159
# 11     Rowlett Bikes       Electric Bikes      412
# 12     Rowlett Bikes       Mountain Bikes      928
# 13     Rowlett Bikes           Road Bikes      646
# 14  Santa Cruz Bikes    Children Bicycles      952
# 15  Santa Cruz Bikes     Comfort Bicycles      425
# 16  Santa Cruz Bikes    Cruisers Bicycles     1093
# 17  Santa Cruz Bikes  Cyclocross Bicycles      158
# 18  Santa Cruz Bikes       Electric Bikes      368
# 19  Santa Cruz Bikes       Mountain Bikes      849
# 20  Santa Cruz Bikes           Road Bikes      687

# %%
result1.dtypes
# Out:
# store_name       object
# category_name    object
# sum_qty           int64
# dtype: object

# %%
store = result1['store_name'].unique()
result1['store_name'] = pd.Categorical(result1['store_name'], categories= store,ordered = True)

category = result1['category_name'].unique()
result1['category_name'] = pd.Categorical(result1['category_name'], categories= category, ordered = True)

# %%
result1.dtypes
# Out:
# store_name       category
# category_name    category
# sum_qty             int64
# dtype: object

# %%
result1 = result1.groupby(['category_name','store_name'])['sum_qty'].sum().unstack().fillna(0)

ax = result1.plot(kind='bar',figsize = (20,20))
plt.title('Number of stocks based on category name and store name')
plt.xlabel('Category')
plt.ylabel('Quantity')
plt.xticks(rotation = 0)

plt.show()

# %% [markdown]
# ### Number of ordered items based on category name and store name

# %%
query2 ='''
SELECT store_name, category_name, SUM(quantity) AS sum_qty
FROM categories
JOIN products ON categories.category_id = products.category_id
JOIN order_items ON products.product_id = order_items.product_id
JOIN orders ON order_items.order_id = orders.order_id
JOIN stores ON orders.store_id = stores.store_id
GROUP BY store_name, category_name
ORDER BY store_name, category_name;
'''

result2 = pd.read_sql_query(query2,db)
result2
# Out:
#           store_name        category_name  sum_qty
# 0      Baldwin Bikes    Children Bicycles      811
# 1      Baldwin Bikes     Comfort Bicycles      555
# 2      Baldwin Bikes    Cruisers Bicycles     1396
# 3      Baldwin Bikes  Cyclocross Bicycles      271
# 4      Baldwin Bikes       Electric Bikes      202
# 5      Baldwin Bikes       Mountain Bikes     1170
# 6      Baldwin Bikes           Road Bikes      374
# 7      Rowlett Bikes    Children Bicycles      117
# 8      Rowlett Bikes     Comfort Bicycles       87
# 9      Rowlett Bikes    Cruisers Bicycles      245
# 10     Rowlett Bikes  Cyclocross Bicycles       32
# 11     Rowlett Bikes       Electric Bikes       33
# 12     Rowlett Bikes       Mountain Bikes      197
# 13     Rowlett Bikes           Road Bikes       72
# 14  Santa Cruz Bikes    Children Bicycles      251
# 15  Santa Cruz Bikes     Comfort Bicycles      171
# 16  Santa Cruz Bikes    Cruisers Bicycles      422
# 17  Santa Cruz Bikes  Cyclocross Bicycles       91
# 18  Santa Cruz Bikes       Electric Bikes       80
# 19  Santa Cruz Bikes       Mountain Bikes      388
# 20  Santa Cruz Bikes           Road Bikes      113

# %%
result2.dtypes
# Out:
# store_name       object
# category_name    object
# sum_qty           int64
# dtype: object

# %%
store = result2['store_name'].unique()
result2['store_name'] = pd.Categorical(result2['store_name'], categories = store, ordered = True)

category = result2['category_name'].unique()
result2['category_name'] = pd.Categorical(result2['category_name'], categories = category, ordered = True)

# %%
result2.dtypes
# Out:
# store_name       category
# category_name    category
# sum_qty             int64
# dtype: object

# %%
result2 = result2.groupby(['category_name', 'store_name'])['sum_qty'].sum().unstack().fillna(0)

ax = result2.plot(kind='bar',figsize = (20,20))
plt.title('Number of ordered items based on category name and store name')
plt.xlabel('Category')
plt.ylabel('Quantity')
plt.xticks(rotation = 0)

plt.show()

# %% [markdown]
# ### Total sales in Santa Cruz bikes based on Year and Month

# %%
query3 ='''
SELECT STRFTIME('%Y %m', order_date) AS year_month, SUM(quantity * list_price * (1 - discount)) AS total_price
FROM order_items
JOIN orders ON order_items.order_id = orders.order_id
JOIN stores ON orders.store_id = stores.store_id
WHERE store_name = 'Santa Cruz Bikes'
GROUP BY year_month
ORDER BY year_month;
'''

result3 = pd.read_sql_query(query3,db)
result3
# Out:
#    year_month  total_price
# 0     2016 01   71760.3064
# 1     2016 02   35255.4513
# 2     2016 03   46817.6251
# 3     2016 04   34230.6401
# 4     2016 05   28095.2399
# 5     2016 06   41554.1683
# 6     2016 07   21258.8857
# 7     2016 08   44803.6003
# 8     2016 09   65159.6319
# 9     2016 10   69175.4980
# 10    2016 11   55771.3843
# 11    2016 12   51611.0782
# 12    2017 01   52937.6554
# 13    2017 02   58902.0125
# 14    2017 03   55460.9753
# 15    2017 04   20607.5748
# 16    2017 05   52097.6926
# 17    2017 06   56720.9109
# 18    2017 07   57073.9615
# 19    2017 08   45000.4881
# 20    2017 09   36178.5697
# 21    2017 10   32258.8614
# 22    2017 11   54307.8571
# 23    2017 12   41361.6818
# 24    2018 01   73982.1779
# 25    2018 02   39637.6433
# 26    2018 03   53015.6861
# 27    2018 04  305047.6787
# 28    2018 07    1956.9715
# 29    2018 10    3781.1284

# %%
result3.dtypes
# Out:
# year_month      object
# total_price    float64
# dtype: object

# %%
result3['year_month'] = pd.to_datetime(result3['year_month'], format = '%Y %m')

# %%
result3.dtypes
# Out:
# year_month     datetime64[ns]
# total_price           float64
# dtype: object

# %%
plt.subplots(figsize=(20, 20))

plt.plot(result3['year_month'], result3['total_price'])
plt.title('Total sales in Santa Cruz Bikes based on year month')
plt.xlabel('year month')
plt.ylabel('number of rents')
plt.ylim(bottom = 0)

plt.show()

# %% [markdown]
# ### Total Sales in Baldwin bikes based on Year Month

# %%
query4 ='''
SELECT STRFTIME('%Y %m', order_date) AS year_month, SUM(quantity * list_price * (1 - discount)) AS total_price
FROM order_items
JOIN orders ON order_items.order_id = orders.order_id
JOIN stores ON orders.store_id = stores.store_id
WHERE store_name = 'Baldwin Bikes'
GROUP BY year_month
ORDER BY year_month;
'''

result4 = pd.read_sql_query(query4,db)
result4
# Out:
#    year_month  total_price
# 0     2016 01  132894.2968
# 1     2016 02  102201.9071
# 2     2016 03  110338.7916
# 3     2016 04  120491.9842
# 4     2016 05  150679.6523
# 5     2016 06  139021.3866
# 6     2016 07  167320.8731
# 7     2016 08  142994.2888
# 8     2016 09  164368.6516
# 9     2016 10  129251.7324
# 10    2016 11   95705.8019
# 11    2016 12  135329.5141
# 12    2017 01  217406.6490
# 13    2017 02  197814.7258
# 14    2017 03  219582.6878
# 15    2017 04  161639.9347
# 16    2017 05  201407.9959
# 17    2017 06  250491.8029
# 18    2017 07  171303.2829
# 19    2017 08  193430.8581
# 20    2017 09  203956.7509
# 21    2017 10  256674.0375
# 22    2017 11  209155.0894
# 23    2017 12  196824.5810
# 24    2018 01  262508.3779
# 25    2018 02  139945.0584
# 26    2018 03  282956.9115
# 27    2018 04  437264.9112
# 28    2018 06     188.9910
# 29    2018 08    8377.8147
# 30    2018 09    8963.9647
# 31    2018 11    5257.9717

# %%
result4.dtypes
# Out:
# year_month      object
# total_price    float64
# dtype: object

# %%
result4['year_month'] = pd.to_datetime(result4['year_month'], format = '%Y %m')

# %%
result4.dtypes
# Out:
# year_month     datetime64[ns]
# total_price           float64
# dtype: object

# %%
plt.subplots(figsize=(20, 20))

plt.plot(result4['year_month'], result4['total_price'])
plt.title('Total sales in Baldwin Bikes based on year month')
plt.xlabel('year month')
plt.ylabel('total sales')
plt.ylim(bottom = 0)

plt.show()

# %% [markdown]
# ### Total Sales in Rowlett Bikes based on Year Month

# %%
query5 ='''
SELECT STRFTIME('%Y %m', order_date) AS year_month, SUM(quantity * list_price * (1 - discount)) AS total_price
FROM order_items
JOIN orders ON order_items.order_id = orders.order_id
JOIN stores ON orders.store_id = stores.store_id
WHERE store_name = 'Rowlett Bikes'
GROUP BY year_month
ORDER BY year_month;
'''

result5 = pd.read_sql_query(query5,db)
result5
# Out:
#    year_month  total_price
# 0     2016 01   10491.8209
# 1     2016 02   18654.9644
# 2     2016 03   23443.9118
# 3     2016 04   12421.4269
# 4     2016 05   26495.1169
# 5     2016 06   29986.5696
# 6     2016 07   10977.0501
# 7     2016 08   37859.4876
# 8     2016 09   43563.3262
# 9     2016 10   13650.8501
# 10    2016 11   30852.2262
# 11    2016 12   12889.3869
# 12    2017 01   15272.1796
# 13    2017 02   56207.0087
# 14    2017 03   33868.2387
# 15    2017 04   45043.4036
# 16    2017 05   14727.5494
# 17    2017 06   71652.9397
# 18    2017 07    1618.1535
# 19    2017 08   52122.1092
# 20    2017 09   53269.9355
# 21    2017 10   21395.4101
# 22    2017 11   18114.9554
# 23    2017 12   21319.7221
# 24    2018 01   44939.5435
# 25    2018 02   21075.3598
# 26    2018 03   28018.3959
# 27    2018 04   75609.2705
# 28    2018 07    9380.9287
# 29    2018 11    6104.0354
# 30    2018 12    6516.9667

# %%
result5.dtypes
# Out:
# year_month      object
# total_price    float64
# dtype: object

# %%
result5['year_month'] = pd.to_datetime(result5['year_month'], format = '%Y %m')

# %%
result5.dtypes
# Out:
# year_month     datetime64[ns]
# total_price           float64
# dtype: object

# %%
plt.subplots(figsize=(20, 20))

plt.plot(result5['year_month'], result5['total_price'])
plt.title('Total sales in Rowlett Bikes based on year month')
plt.xlabel('year month')
plt.ylabel('total sales')
plt.ylim(bottom = 0)

plt.show()

# %% [markdown]
# ### Staff with highest number of orders

# %%
query6 ='''
SELECT staffs.staff_id, staffs.first_name, staffs.last_name, COUNT(orders.order_id) AS numberof_orders
FROM orders
JOIN staffs ON orders.staff_id = staffs.staff_id
GROUP BY staffs.staff_id
HAVING numberof_orders = (SELECT MAX(x)
                          FROM (SELECT s.staff_id, s.first_name, s.last_name, COUNT(o.order_id) AS x
                                FROM orders AS o
                                JOIN staffs AS s ON o.staff_id = s.staff_id
                                GROUP BY s.staff_id) AS y)
'''

result6 = pd.read_sql_query(query6,db)
result6
# Out:
#    staff_id first_name last_name  numberof_orders
# 0         6  Marcelene     Boyer              553

# %% [markdown]
# ### Staff with lowest number of orders

# %%
query7 ='''
SELECT staffs.staff_id, staffs.first_name, staffs.last_name, COUNT(orders.order_id) AS numberof_orders
FROM orders
JOIN staffs ON orders.staff_id = staffs.staff_id
GROUP BY staffs.staff_id
HAVING numberof_orders = (SELECT MIN(x)
                          FROM (SELECT s.staff_id, s.first_name, s.last_name, COUNT(o.order_id) AS x
                                FROM orders AS o
                                JOIN staffs AS s ON o.staff_id = s.staff_id
                                GROUP BY s.staff_id) AS y)
'''

result7 = pd.read_sql_query(query7,db)
result7
# Out:
#    staff_id first_name last_name  numberof_orders
# 0         9      Layla   Terrell               86
